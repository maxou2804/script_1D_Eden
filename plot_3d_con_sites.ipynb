# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np


c_list = []
colors = ('r', 'g', 'b', 'k')




alpha_20000 =[np.float64(0.46268919506882333), np.float64(0.6033237128884384), np.float64(0.6254124387452972), np.float64(0.6118234966730977),
               np.float64(0.5925798171609653), np.float64(0.6265336267185865), np.float64(0.5435799501820078), np.float64(0.6048234026236424), np.float64(0.6034854304966788)]

beta_20000 = [np.float64(0.3204496503688474), np.float64(0.494380240943281), np.float64(0.6035262161455871), np.float64(0.6269710446988108), 
              np.float64(0.6352624807030549), np.float64(0.6732300007580753), np.float64(0.7144527264620368), np.float64(0.7073466336525863), np.float64(0.7991798124970698)]

p_20000 = np.array([0.0, 0.0000025, 0.000005, 0.0000075, 0.00001, 0.0000125, 0.000015, 0.0000175, 0.00002])*20000

alpha_10000 =[np.float64(0.46268919506882333), np.float64(0.5896345839277761), np.float64(0.5915722655031275), np.float64(0.5729312803527072), np.float64(0.5588524266429957), 
              np.float64(0.5977339239961956), np.float64(0.5681793155638979), np.float64(0.605766435689824), np.float64(0.5905904088270605)]
beta_10000 = [np.float64(0.3204496503688474), np.float64(0.4545867804622376), np.float64(0.5690297957707512), np.float64(0.679229159589012), np.float64(0.6818497320575133),
               np.float64(0.6997267638926229), np.float64(0.7221634387690126), np.float64(0.7691116993825441), np.float64(0.774576416149401)]

p_10000 = np.array([0.0, 0.000005, 0.00001, 0.000015, 0.00002, 0.000025, 0.00003, 0.000035, 0.00004])*10000

alpha_5000 =[np.float64(0.46268919506882333), np.float64(0.5998170906921139), np.float64(0.5787477530810975), np.float64(0.6157149761762303), np.float64(0.5706989716861548), 
             np.float64(0.6075611557636945), np.float64(0.5589674848644044), np.float64(0.5843976306169676), np.float64(0.6295547852358369)]

beta_5000 =[np.float64(0.3204496503688474), np.float64(0.5103992648403795), np.float64(0.6753640732086981), np.float64(0.679661391907461), np.float64(0.7376958014058719), 
            np.float64(0.7500718178633597), np.float64(0.7846605479755578), np.float64(0.8059949394029176), np.float64(0.7923738426842093)]

p_5000 = np.array([0.0, 0.00001, 0.00002, 0.00003, 0.00004, 0.00005, 0.00006, 0.00007, 0.00008])*5000

alpha_1000 = [np.float64(0.46268919506882333), np.float64(0.5183360733847752), np.float64(0.5736855691607118), np.float64(0.5455993147405421), 
              np.float64(0.569396671188998), np.float64(0.5535275855114479), np.float64(0.5692950551799499), np.float64(0.5371451970209795), np.float64(0.5200211050528842)]
beta_1000 = [np.float64(0.3204496503688474), np.float64(0.5185232448533443), np.float64(0.6294964385376651), np.float64(0.6848911873916134),
              np.float64(0.7266113990303228), np.float64(0.7305202830732527), np.float64(0.743385700976857), np.float64(0.773235374126314), np.float64(0.857735738572185)]

p_1000 = np.array([0.0, 0.00005, 0.0001, 0.00015, 0.0002, 0.00025, 0.0003, 0.00035, 0.0004])*1000

alpha_500 =[np.float64(0.46268919506882333), np.float64(0.5534218777426428), np.float64(0.4993735930939029), np.float64(0.5497234401867421), np.float64(0.5551905061350841), 
            np.float64(0.5703699096736408), np.float64(0.5707954335305945), np.float64(0.5512163584234245), np.float64(0.5596113454082088)]


beta_500 =[np.float64(0.3204496503688474), np.float64(0.5464887098777536), np.float64(0.5968023504516755), np.float64(0.6211526366505952), np.float64(0.6998541612830288), 
           np.float64(0.7056866123522634), np.float64(0.7279494608358474), np.float64(0.7664188760236071), np.float64(0.8227949246535539)]



p_500 = np.array([0.0, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008])*500

alpha_300= [np.float64(0.46268919506882333), np.float64(0.45828155711681257), np.float64(0.5411488947157764), np.float64(0.5528509480538801), np.float64(0.553407084803449),
            np.float64(0.5605557379261783), np.float64(0.5407727979131363), np.float64(0.5091123743393857), np.float64(0.576688536055062)]
beta_300 = [np.float64(0.3204496503688474), np.float64(0.49995087678437644), np.float64(0.5616690715583369), np.float64(0.6000056988187962), np.float64(0.6763385788976113), 
            np.float64(0.6610145794351697), np.float64(0.7108195219528594), np.float64(0.7248140238771776), np.float64(0.7339857842784526)]


p_300 = np.array([0.0, 0.00016667, 0.00033333, 0.0005, 0.00066667, 0.00083333, 0.001, 0.00116667, 0.00133333])*300

alpha_1 =[np.float64(0.46268919506882333), np.float64(0.4470070611028423), np.float64(0.41341958491721215), np.float64(0.4310501062387391), np.float64(0.44651889560116875), 
          np.float64(0.4289153696649693), np.float64(0.49901781784948596), np.float64(0.558869205280798), np.float64(0)]
 
beta_1 = [np.float64(0.3204496503688474), np.float64(0.33375695647843356), np.float64(0.3589976767516016), np.float64(0.36607061365770105), np.float64(0.39723050258237663),
            np.float64(0.4510440582964586), np.float64(0.5060042662833594), np.float64(0.7812024342104521), np.float64(0)]

p_1 = np.array([0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4])


print(p_20000)
# Out:
# [0.   0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4 ]

# %%
import matplotlib.pyplot as plt

# -------------------------
# Pack all your datasets
# -------------------------
alpha_data = {
    1:     (p_1, alpha_1),
    300:   (p_300, alpha_300),
    500:   (p_500, alpha_500),
    1000:  (p_1000, alpha_1000),
    5000:  (p_5000, alpha_5000),
    10000: (p_10000, alpha_10000),
    20000: (p_20000, alpha_20000)
}

beta_data = {
    1:     (p_1, beta_1),
    300:   (p_300, beta_300),
    500:   (p_500, beta_500),
    1000:  (p_1000, beta_1000),
    5000:  (p_5000, beta_5000),
    10000: (p_10000, beta_10000),
    20000: (p_20000, beta_20000)
}

colors = ['red', 'green', 'blue', 'orange', 'purple', 'cyan', 'black']
markers = ['o', 's', '^', 'D', 'v', 'x', '*']

# -------------------------
# PLOT α(p)
# -------------------------
plt.figure(figsize=(10,6))

for (L, (p, alpha)), color, marker in zip(alpha_data.items(), colors, markers):
    plt.plot(p, alpha, marker=marker, color=color, label=f"α (s={L})", linewidth=2)

plt.plot(p,0.5*np.ones((len(p),1)),'--')
plt.text(-0.02,0.43,'KPZ α=0.5',fontsize=14)
plt.plot(p,0.633*np.ones((len(p),1)),'--')
plt.text(-0.02,0.60,'qKPZ α=0.633',fontsize=14)
plt.xlabel("p × s",fontsize=16)
plt.ylabel("α",fontsize=16)
plt.title("Scaling exponent α as a function of p",fontsize=16)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# -------------------------
# PLOT β(p)
# -------------------------
plt.figure(figsize=(10,6))

for (L, (p, beta)), color, marker in zip(beta_data.items(), colors, markers):
    plt.plot(p, beta, marker=marker, color=color, label=f"β (s={L})", linewidth=2)
plt.text(0.0,0.67,'qKPZ β=0.633',fontsize=14)
plt.plot(p,0.633*np.ones((len(p),1)),'--')
plt.text(0.0,0.25,'KPZ β=0.333',fontsize=14)
plt.plot(p,0.333*np.ones((len(p),1)),'--')
plt.xlabel("p × s",fontsize=16)
plt.ylabel("β",fontsize=16)
plt.title("Scaling exponent β as a function of p",fontsize=16)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import plotly.graph_objects as go
import numpy as np

# Organize all data
# =============================================

p = [p_1, p_300, p_500, p_1000, p_5000, p_10000, p_20000]
beta = [beta_1, beta_300, beta_500, beta_1000, beta_5000, beta_10000, beta_20000]
alpha = [alpha_1, alpha_300, alpha_500, alpha_1000, alpha_5000, alpha_10000, alpha_20000]
names = ['1', '300', '500', '1000', '5000', '10000', '20000']

# =============================================
# Build interactive plot
# =============================================
fig = go.Figure()

for idx in range(7):
    x = np.array(p[idx])
    y = [idx] * len(x)
    z = beta[idx]

    fig.add_trace(go.Scatter3d(
        x=x, y=y, z=z,
        mode='lines+markers',
        name=f"Size {names[idx]}",
        marker=dict(size=5),
    ))

# =============================================
# Add transparent highlight box for β ∈ [0.28, 0.38]
# =============================================

# Find x-axis range (max probability across all datasets)
x_max = max([max(p[i]) for i in range(7)])

# Box corners
x_min, x_max = 0, x_max
y_min, y_max = 0, 6  # covers all 7 curves (0 to 6)
z_min, z_max = 0.28, 0.38

# 8 vertices of the cuboid
X = [x_min, x_max, x_max, x_min, x_min, x_max, x_max, x_min]
Y = [y_min, y_min, y_max, y_max, y_min, y_min, y_max, y_max]
Z = [z_min, z_min, z_min, z_min, z_max, z_max, z_max, z_max]

fig.add_trace(go.Mesh3d(
    x=X, y=Y, z=Z,
    opacity=0.25,
    color='yellow',
    flatshading=False,
    name='β range 0.28–0.38',
    showscale=False,
    alphahull=0
))

# =============================================
# Axis labels and formatting
# =============================================

fig.update_layout(
    scene=dict(
        xaxis_title='probabilities',
        yaxis_title='size',
        zaxis_title='beta value',
        yaxis=dict(
            tickmode='array',
            tickvals=list(range(7)),
            ticktext=names
        )
    ),
    width=1000,
    height=800,
    title='Interactive 3D Plot: Beta vs Probability vs Size (All Datasets)'
)

fig.show()

# %%
import plotly.graph_objects as go
import numpy as np

# Organize all data
# =============================================

p = [p_1, p_300, p_500, p_1000, p_5000, p_10000, p_20000]
beta = [beta_1, beta_300, beta_500, beta_1000, beta_5000, beta_10000, beta_20000]
alpha = [alpha_1, alpha_300, alpha_500, alpha_1000, alpha_5000, alpha_10000, alpha_20000]
names = ['1', '300', '500', '1000', '5000', '10000', '20000']

# =============================================
# Build interactive plot
# =============================================
fig = go.Figure()

for idx in range(7):
    x = np.array(p[idx])
    y = [idx] * len(x)
    z = alpha[idx]

    fig.add_trace(go.Scatter3d(
        x=x, y=y, z=z,
        mode='lines+markers',
        name=f"Size {names[idx]}",
        marker=dict(size=5),
    ))

# =============================================
# Add transparent highlight box for β ∈ [0.28, 0.38]
# =============================================

# Find x-axis range (max probability across all datasets)
x_max = max([max(p[i]) for i in range(7)])

# Box corners
x_min, x_max = 0, x_max
y_min, y_max = 0, 6  # covers all 7 curves (0 to 6)
z_min, z_max = 0.45, 0.55

# 8 vertices of the cuboid
X = [x_min, x_max, x_max, x_min, x_min, x_max, x_max, x_min]
Y = [y_min, y_min, y_max, y_max, y_min, y_min, y_max, y_max]
Z = [z_min, z_min, z_min, z_min, z_max, z_max, z_max, z_max]

fig.add_trace(go.Mesh3d(
    x=X, y=Y, z=Z,
    opacity=0.25,
    color='yellow',
    flatshading=False,
    name='β range 0.28–0.38',
    showscale=False,
    alphahull=0
))

# =============================================
# Axis labels and formatting
# =============================================

fig.update_layout(
    scene=dict(
        xaxis_title='probabilities',
        yaxis_title='size',
        zaxis_title='alpha value',
        yaxis=dict(
            tickmode='array',
            tickvals=list(range(7)),
            ticktext=names
        )
    ),
    width=1000,
    height=800,
    title='Interactive 3D Plot: Alpha vs Probability vs Size (All Datasets)'
)

fig.show()

# %%
# Out:
# SignificanceResult(statistic=-0.3768511731740915, pvalue=0.46148284035080467)
