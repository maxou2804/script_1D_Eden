                        np.float64(0.616598442312165), np.float64(0.5738058243818942), np.float64(0.6375888433898403), np.float64(0.6250230414071708)]
beta_ref_acceleration=[np.float64(0.3204496503688474), np.float64(0.24885347367361998), np.float64(0.29866548584167996), np.float64(0.25331562940447), np.float64(0.21554845910756407),
                        np.float64(0.20814124334142103), np.float64(0.23696945022827617), np.float64(0.2907520949050852), np.float64(0.26001922930112753)]


p_1=[0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4]

# %%
import matplotlib.pyplot as plt
import math
# -------------------------
# Pack all your datasets
# -------------------------
alpha_data = {
    0.25:      (p_1, alpha_0_25),
    0.50:      (p_1,  alpha_0_5),
    1:       (p_1, alpha_1),
    2:     (p_1,  alpha_2),
    0 :   (p_1, alpha_ref_constraint),
    math.inf:       (p_1,alpha_ref_acceleration)
}

beta_data = {
    0.25:      (p_1, beta_0_25),
    0.50:      (p_1,  beta_0_5),
    1:       (p_1, beta_1),
    2:     (p_1,  beta_2),
    0:   (p_1, beta_ref_constraint),
    math.inf:       (p_1,beta_ref_acceleration)
}

colors = ['red', 'green', 'blue', 'orange', 'purple', 'cyan']
markers = ['o', 's', '^', 'D', 'v', 'x']

# -------------------------
# PLOT α(p)
# -------------------------
plt.figure(figsize=(10,6))

for (L, (p, alpha)), color, marker in zip(alpha_data.items(), colors, markers):
    plt.plot(p, alpha, marker=marker, color=color, label=f"α ($s_a/s_c$={L})", linewidth=2)

plt.plot(p,0.5*np.ones((len(p),1)),'--')
plt.text(0.13,0.49,'KPZ α=0.5',fontsize=14)
plt.plot(p,0.633*np.ones((len(p),1)),'--')
plt.text(0.12,0.643,'qKPZ α=0.633',fontsize=14)
plt.xlabel("p × system size",fontsize=16)
plt.ylabel("α",fontsize=16)
plt.title("Scaling exponent α as a function of p",fontsize=16)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# -------------------------
# PLOT β(p)
# -------------------------
plt.figure(figsize=(10,6))

for (L, (p, beta)), color, marker in zip(beta_data.items(), colors, markers):
    plt.plot(p, beta, marker=marker, color=color, label=f"β ($s_a/s_c$={L})", linewidth=2)

plt.text(0.0,0.58,'qKPZ β=0.633',fontsize=14)
plt.plot(p,0.633*np.ones((len(p),1)),'--')
plt.text(0.12,0.37,'KPZ β=0.333',fontsize=14)
plt.plot(p,0.333*np.ones((len(p),1)),'--')
plt.text(0.027,0.2,'EW β=0.25',fontsize=14)
plt.plot(p,0.25*np.ones((len(p),1)),'--')
plt.xlabel("p × system size",fontsize=16)
plt.ylabel("β",fontsize=16)
plt.title("Scaling exponent β as a function of p",fontsize=16)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import plotly.graph_objects as go
import numpy as np

# Organize all data
# =============================================

p = [p_1,p_1,p_1, p_1,p_1,p_1]
beta = [beta_0_25,beta_0_5, beta_1,beta_2,beta_ref_constraint,beta_ref_acceleration]
alpha = [alpha_0_25,alpha_0_5,alpha_1,alpha_2,alpha_ref_constraint,alpha_ref_acceleration]
names = ['0_25','0.5', '1', '2','ref_constraint_1000','ref_acceleration_1000']

# =============================================
# Build interactive plot
# =============================================
fig = go.Figure()

for idx in range(6):
    x = np.array(p[idx])
    y = [idx] * len(x)
    z = beta[idx]

    fig.add_trace(go.Scatter3d(
        x=x, y=y, z=z,
        mode='lines+markers',
        name=f"Size {names[idx]}",
        marker=dict(size=5),
    ))

# =============================================
# Add transparent highlight box for β ∈ [0.28, 0.38]
# =============================================

# Find x-axis range (max probability across all datasets)
x_max = max([max(p[i]) for i in range(6)])

# Box corners
x_min, x_max = 0, x_max
y_min, y_max = 0, 5  # covers all 7 curves (0 to 6)
z_min, z_max = 0.28, 0.38

# 8 vertices of the cuboid
X = [x_min, x_max, x_max, x_min, x_min, x_max, x_max, x_min]
Y = [y_min, y_min, y_max, y_max, y_min, y_min, y_max, y_max]
Z = [z_min, z_min, z_min, z_min, z_max, z_max, z_max, z_max]

fig.add_trace(go.Mesh3d(
    x=X, y=Y, z=Z,
    opacity=0.25,
    color='yellow',
    flatshading=False,
    name='β range 0.28–0.38',
    showscale=False,
    alphahull=0
))

# =============================================
# Axis labels and formatting
# =============================================

fig.update_layout(
    scene=dict(
        xaxis_title='probabilities',
        yaxis_title='size',
        zaxis_title='beta value',
        yaxis=dict(
            tickmode='array',
            tickvals=list(range(6)),
            ticktext=names
        )
    ),
    width=1000,
    height=800,
    title='Interactive 3D Plot: Beta vs Probability vs Size (All Datasets)'
)

fig.show()

# %%
import plotly.graph_objects as go
import numpy as np

# Organize all data
# =============================================



# =============================================
# Build interactive plot
# =============================================
fig = go.Figure()

for idx in range(6):
    x = np.array(p[idx])
    y = [idx] * len(x)
    z = alpha[idx]

    fig.add_trace(go.Scatter3d(
        x=x, y=y, z=z,
        mode='lines+markers',
        name=f"Size {names[idx]}",
        marker=dict(size=5),
    ))

# =============================================
# Add transparent highlight box for β ∈ [0.28, 0.38]
# =============================================

# Find x-axis range (max probability across all datasets)
x_max = max([max(p[i]) for i in range(6)])

# Box corners
x_min, x_max = 0, x_max
y_min, y_max = 0, 5  # covers all 7 curves (0 to 6)
z_min, z_max = 0.45, 0.55

# 8 vertices of the cuboid
X = [x_min, x_max, x_max, x_min, x_min, x_max, x_max, x_min]
Y = [y_min, y_min, y_max, y_max, y_min, y_min, y_max, y_max]
Z = [z_min, z_min, z_min, z_min, z_max, z_max, z_max, z_max]

fig.add_trace(go.Mesh3d(
    x=X, y=Y, z=Z,
    opacity=0.25,
    color='yellow',
    flatshading=False,
    name='alpha range 0.45–0.55',
    showscale=False,
    alphahull=0
))

# =============================================
# Axis labels and formatting
# =============================================

fig.update_layout(
    scene=dict(
        xaxis_title='probabilities',
        yaxis_title='size',
        zaxis_title='alpha value',
        yaxis=dict(
            tickmode='array',
            tickvals=list(range(6)),
            ticktext=names
        )
    ),
    width=1000,
    height=800,
    title='Interactive 3D Plot: Alpha vs Probability vs Size (All Datasets)'
)

fig.show()

# %%
# Out:
# SignificanceResult(statistic=-0.3768511731740915, pvalue=0.46148284035080467)
