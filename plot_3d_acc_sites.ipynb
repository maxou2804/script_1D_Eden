# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np


c_list = []
colors = ('r', 'g', 'b', 'k')




alpha_20000 = [np.float64(0.46268919506882333), np.float64(0.6729483491642938), np.float64(0.6759907198520076), 
               np.float64(0.6648655170651465), np.float64(0.6809760271747918), np.float64(0.6624125064760387), 
               np.float64(0.6649256496233968), np.float64(0.6614211503754595), np.float64(0.6816976376508719)]
beta_20000 = [np.float64(0.3204496503688474), np.float64(0.06802226210611258), np.float64(0.16020753192301374), 
              np.float64(0.15350241451841495), np.float64(0.1398806409982132), np.float64(0.04129827897018431), 
              np.float64(0.10768379736123006), np.float64(0.10575235738050344), np.float64(0.10428593971492595)]
p_20000 = np.array([0.0, 0.0000025, 0.000005, 0.0000075, 0.00001, 0.0000125, 0.000015, 0.0000175, 0.00002])*20000

alpha_10000 = [np.float64(0.46268919506882333), np.float64(0.6638658998659054), np.float64(0.672581777825624), 
               np.float64(0.6291024623591673), np.float64(0.6733464690982057), np.float64(0.6514348670817499), 
               np.float64(0.666786702199836), np.float64(0.6159807751593914), np.float64(0.6082019613505822)]
beta_10000 = [np.float64(0.3204496503688474), np.float64(0.1162581669421224), np.float64(0.11860209376468335), 
              np.float64(0.14589730076492602), np.float64(0.1259941209753148), np.float64(0.24992396781802867), 
              np.float64(0.12190817215129193), np.float64(0.1066805269303964), np.float64(0.1818889426948699)]
p_10000 = np.array([0.0, 0.000005, 0.00001, 0.000015, 0.00002, 0.000025, 0.00003, 0.000035, 0.00004])*10000

alpha_5000 = [np.float64(0.46268919506882333), np.float64(0.6358628190007384), np.float64(0.6667331904544429), 
              np.float64(0.6426891086407559), np.float64(0.6215176387432894), np.float64(0.6390420713402434), 
              np.float64(0.6111326273553928), np.float64(0.6778051517293816), np.float64(0.6031447721646102)]
beta_5000 = [np.float64(0.3204496503688474), np.float64(0.21273752498205645), np.float64(0.13505613084708562), 
             np.float64(0.15147568883235457), np.float64(0.10575626931867341), np.float64(0.17021024642301052), 
             np.float64(0.1290884231719576), np.float64(0.23283887728498037), np.float64(0.126497260761312)]
p_5000 = np.array([0.0, 0.00001, 0.00002, 0.00003, 0.00004, 0.00005, 0.00006, 0.00007, 0.00008])*5000

alpha_1000 = [np.float64(0.46268919506882333), np.float64(0.6510908099227367), np.float64(0.6447213914342658), 
              np.float64(0.6284156015310696), np.float64(0.6431603585141022), np.float64(0.616598442312165), 
              np.float64(0.5738058243818942), np.float64(0.6375888433898403), np.float64(0.6250230414071708)]
beta_1000 = [np.float64(0.3204496503688474), np.float64(0.24885347367361998), np.float64(0.29866548584167996), 
             np.float64(0.25331562940447), np.float64(0.21554845910756407), np.float64(0.20814124334142103), 
             np.float64(0.23696945022827617), np.float64(0.2907520949050852), np.float64(0.26001922930112753)]
p_1000 = np.array([0.0, 0.00005, 0.0001, 0.00015, 0.0002, 0.00025, 0.0003, 0.00035, 0.0004])*1000

alpha_500 = [np.float64(0.46268919506882333), np.float64(0.6400348901420518), np.float64(0.6604169879392026), 
             np.float64(0.6515158699245104), np.float64(0.6210066810449661), np.float64(0.630132784305668), 
             np.float64(0.6579664344260493), np.float64(0.6381065839003367), np.float64(0.5828824240027223)]
beta_500 = [np.float64(0.3204496503688474), np.float64(0.29013929128228827), np.float64(0.24344742839346029), 
            np.float64(0.23626268409646548), np.float64(0.24056059997593918), np.float64(0.2415154465913556), 
            np.float64(0.2335066793362305), np.float64(0.28252680776857914), np.float64(0.18046870006523572)]
p_500 = np.array([0.0, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008])*500

alpha_300 = [np.float64(0.46268919506882333), np.float64(0.5966991449152932), np.float64(0.6266177112994639), 
             np.float64(0.6108432272066222), np.float64(0.6082834109850441), np.float64(0.5921052086738988), 
             np.float64(0.628162457945934), np.float64(0.6420801879776961), np.float64(0.5975708135141874)]
beta_300 = [np.float64(0.3204496503688474), np.float64(0.29390972543854027), np.float64(0.32828683329946917), 
            np.float64(0.21696900879698752), np.float64(0.3281053170355339), np.float64(0.3212173353310018), 
            np.float64(0.2974126916054179), np.float64(0.2409029139014037), np.float64(0.2013808032027623)]
p_300 = np.array([0.0, 0.00016667, 0.00033333, 0.0005, 0.00066667, 0.00083333, 0.001, 0.00116667, 0.00133333])*300

alpha_1 = [np.float64(0.46268919506882333), np.float64(0.5077476923610046), np.float64(0.5292780770852075), 
           np.float64(0.5242541799013171), np.float64(0.573242473014759), np.float64(0.5947347559730042), 
           np.float64(0.2945618722584625), np.float64(0.15517322400441555), np.float64(0.11301688886936709)]
beta_1 = [np.float64(0.3204496503688474), np.float64(0.34538024027088815), np.float64(0.298085425230953), 
          np.float64(0.30954859352970704), np.float64(0.3313552221979226), np.float64(0.23697025876319017), 
          np.float64(0.00020995952293823675), np.float64(-0.007599023393606359), np.float64(-0.005958786370287067)]
p_1 = np.array([0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4])


print(p_20000)
# Out:
# [0.   0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4 ]

# %%
import matplotlib.pyplot as plt

# -------------------------
# Pack all your datasets
# -------------------------
alpha_data = {
    1:     (p_1, alpha_1),
    300:   (p_300, alpha_300),
    500:   (p_500, alpha_500),
    1000:  (p_1000, alpha_1000),
    5000:  (p_5000, alpha_5000),
    10000: (p_10000, alpha_10000),
    20000: (p_20000, alpha_20000)
}

beta_data = {
    1:     (p_1, beta_1),
    300:   (p_300, beta_300),
    500:   (p_500, beta_500),
    1000:  (p_1000, beta_1000),
    5000:  (p_5000, beta_5000),
    10000: (p_10000, beta_10000),
    20000: (p_20000, beta_20000)
}

colors = ['red', 'green', 'blue', 'orange', 'purple', 'cyan', 'black']
markers = ['o', 's', '^', 'D', 'v', 'x', '*']

# -------------------------
# PLOT α(p)
# -------------------------
plt.figure(figsize=(10,6))

for (L, (p, alpha)), color, marker in zip(alpha_data.items(), colors, markers):
    plt.plot(p, alpha, marker=marker, color=color, label=f"α (L={L})", linewidth=2)

plt.plot(p,0.5*np.ones((len(p),1)),'--')
plt.text(0.1,0.47,'KPZ α=0.5',fontsize=14)
plt.plot(p,0.633*np.ones((len(p),1)),'--')
plt.text(-0.02,0.67,'qKPZ α=0.633',fontsize=14)
plt.xlabel("p × system size",fontsize=16)
plt.ylabel("α",fontsize=16)
plt.title("Scaling exponent α as a function of p",fontsize=16)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# -------------------------
# PLOT β(p)
# -------------------------
plt.figure(figsize=(10,6))

for (L, (p, beta)), color, marker in zip(beta_data.items(), colors, markers):
    plt.plot(p, beta, marker=marker, color=color, label=f"β (L={L})", linewidth=2)

plt.text(0.0,0.58,'qKPZ β=0.633',fontsize=14)
plt.plot(p,0.633*np.ones((len(p),1)),'--')
plt.text(0.0,0.37,'KPZ β=0.333',fontsize=14)
plt.plot(p,0.333*np.ones((len(p),1)),'--')
plt.text(0.075,0.2,'EW β=0.25',fontsize=14)
plt.plot(p,0.25*np.ones((len(p),1)),'--')
plt.xlabel("p × system size",fontsize=16)
plt.ylabel("β",fontsize=16)
plt.title("Scaling exponent β as a function of p",fontsize=16)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import plotly.graph_objects as go
import numpy as np

# Organize all data
# =============================================

p = [p_1, p_300, p_500, p_1000, p_5000, p_10000, p_20000]
beta = [beta_1, beta_300, beta_500, beta_1000, beta_5000, beta_10000, beta_20000]
alpha = [alpha_1, alpha_300, alpha_500, alpha_1000, alpha_5000, alpha_10000, alpha_20000]
names = ['1', '300', '500', '1000', '5000', '10000', '20000']

# =============================================
# Build interactive plot
# =============================================
fig = go.Figure()

for idx in range(7):
    x = np.array(p[idx])
    y = [idx] * len(x)
    z = beta[idx]

    fig.add_trace(go.Scatter3d(
        x=x, y=y, z=z,
        mode='lines+markers',
        name=f"Size {names[idx]}",
        marker=dict(size=5),
    ))

# =============================================
# Add transparent highlight box for β ∈ [0.28, 0.38]
# =============================================

# Find x-axis range (max probability across all datasets)
x_max = max([max(p[i]) for i in range(7)])

# Box corners
x_min, x_max = 0, x_max
y_min, y_max = 0, 6  # covers all 7 curves (0 to 6)
z_min, z_max = 0.28, 0.38

# 8 vertices of the cuboid
X = [x_min, x_max, x_max, x_min, x_min, x_max, x_max, x_min]
Y = [y_min, y_min, y_max, y_max, y_min, y_min, y_max, y_max]
Z = [z_min, z_min, z_min, z_min, z_max, z_max, z_max, z_max]

fig.add_trace(go.Mesh3d(
    x=X, y=Y, z=Z,
    opacity=0.25,
    color='yellow',
    flatshading=False,
    name='β range 0.28–0.38',
    showscale=False,
    alphahull=0
))

# =============================================
# Axis labels and formatting
# =============================================

fig.update_layout(
    scene=dict(
        xaxis_title='probabilities',
        yaxis_title='size',
        zaxis_title='beta value',
        yaxis=dict(
            tickmode='array',
            tickvals=list(range(7)),
            ticktext=names
        )
    ),
    width=1000,
    height=800,
    title='Interactive 3D Plot: Beta vs Probability vs Size (All Datasets)'
)

fig.show()

# %%
import plotly.graph_objects as go
import numpy as np

# Organize all data
# =============================================

p = [p_1, p_300, p_500, p_1000, p_5000, p_10000, p_20000]
beta = [beta_1, beta_300, beta_500, beta_1000, beta_5000, beta_10000, beta_20000]
alpha = [alpha_1, alpha_300, alpha_500, alpha_1000, alpha_5000, alpha_10000, alpha_20000]
names = ['1', '300', '500', '1000', '5000', '10000', '20000']

# =============================================
# Build interactive plot
# =============================================
fig = go.Figure()

for idx in range(7):
    x = np.array(p[idx])
    y = [idx] * len(x)
    z = alpha[idx]

    fig.add_trace(go.Scatter3d(
        x=x, y=y, z=z,
        mode='lines+markers',
        name=f"Size {names[idx]}",
        marker=dict(size=5),
    ))

# =============================================
# Add transparent highlight box for β ∈ [0.28, 0.38]
# =============================================

# Find x-axis range (max probability across all datasets)
x_max = max([max(p[i]) for i in range(7)])

# Box corners
x_min, x_max = 0, x_max
y_min, y_max = 0, 6  # covers all 7 curves (0 to 6)
z_min, z_max = 0.45, 0.55

# 8 vertices of the cuboid
X = [x_min, x_max, x_max, x_min, x_min, x_max, x_max, x_min]
Y = [y_min, y_min, y_max, y_max, y_min, y_min, y_max, y_max]
Z = [z_min, z_min, z_min, z_min, z_max, z_max, z_max, z_max]

fig.add_trace(go.Mesh3d(
    x=X, y=Y, z=Z,
    opacity=0.25,
    color='yellow',
    flatshading=False,
    name='β range 0.28–0.38',
    showscale=False,
    alphahull=0
))

# =============================================
# Axis labels and formatting
# =============================================

fig.update_layout(
    scene=dict(
        xaxis_title='probabilities',
        yaxis_title='size',
        zaxis_title='alpha value',
        yaxis=dict(
            tickmode='array',
            tickvals=list(range(7)),
            ticktext=names
        )
    ),
    width=1000,
    height=800,
    title='Interactive 3D Plot: Alpha vs Probability vs Size (All Datasets)'
)

fig.show()

# %%
# Out:
# SignificanceResult(statistic=-0.3768511731740915, pvalue=0.46148284035080467)
